# %% [markdown]
# # Word2Vec in non-NLP context
#
# ### In this notebook, we enconde movies' cast and crew into vectors and use them  to predict the probability of any given movie being among the 1% with most IMDB votes

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_auc_score, f1_score, fbeta_score, precision_score, recall_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.model_selection import ParameterGrid
from sklearn.base import BaseEstimator, TransformerMixin
from tqdm.notebook import tqdm
import csv
from gensim.models.callbacks import CallbackAny2Vec
from itertools import groupby
from gensim.models import Word2Vec
import gensim
from pathlib import Path
import matplotlib.pyplot as plt
pd.options.display.max_columns = 999

# %%
# PATH = Path('../../data')
PATH = Path('C:/Users/gmanf/OneDrive/Documents/Data Science/Curso ML Practico/ml-practico\data_kaggle')

# %% [markdown]
# # Load Data

# %%
def load_data(start_year, min_minutes, min_votes):
    title_basics = pd.read_csv(PATH / 'title.basics.tsv', sep='\t')
    title_ratings = pd.read_csv(PATH / 'title.ratings.tsv', sep='\t')
    title_basics.genres = title_basics.genres.apply(
                                        lambda x: x.split(',') if ((type(x)!=float) & (x!=r'\N')) else ['no_genre'])

    title_basics.runtimeMinutes = (
        title_basics.runtimeMinutes.apply(lambda x: np.nan if not x.isdigit() else x).astype(float)
                                )
    
    title_basics = title_basics[
        title_basics.titleType.isin(['movie'])
        & ~title_basics.runtimeMinutes.isna()
        & (title_basics.runtimeMinutes <= 3.5 * 60)
        & title_basics.genres.apply(lambda x: 'Short' not in x)
        ]
    
    movies = pd.merge(title_basics, title_ratings, on='tconst', how='left')
    movies['startYear'] = movies['startYear'].apply(lambda x: np.nan if x == r'\N' else int(x))
    
    # MY CONDITIONS:
    movies = movies[movies.startYear > start_year].dropna(subset=['averageRating'])
    movies = movies[movies.runtimeMinutes >= min_minutes]
    movies = movies[movies.numVotes>=min_votes]
    return movies

# %%
PATH = Path('C:/Users/gmanf/OneDrive/Documents/Data Science/Curso ML Practico/ml-practico\data_kaggle')

# %% [markdown]
# I impose a couple of conditions to make the dataset more manageable:
#
# 1- Only load movies from after 1960, as I suspect films older than that have a different voting pattern. The choice of 1960 as the cutoff is kind of subjective though.
#
# 2- Only load movies > 60 minutes long. It appears that the convention of the minimum duration to be considered a movie is either 40 or 80 minutes depending on the source. So I take 60 minutes which is in the middle of both and makes sense to me.
#
# 3- Only load movies with at least 15 votes. With this we get rid of entries that are not even worth looking into (less than 15 votes means that not even the people involved in the movie appears to have voted for it).

# %%
movies = load_data(start_year = 1960, min_minutes = 60, min_votes = 15)
# Out:
# C:\Users\gmanf\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
principals = pd.read_csv(PATH / 'title.principals.tsv', delimiter="\t")

# %%
movies.head(2)
# Out:
#           tconst titleType    primaryTitle   originalTitle  isAdult  \
# 3591   tt0015724     movie   Dama de noche   Dama de noche        0
# 16751  tt0035423     movie  Kate & Leopold  Kate & Leopold        0
#
#        startYear endYear  runtimeMinutes                      genres  \
# 3591      1993.0      \N           102.0   [Drama, Mystery, Romance]
# 16751     2001.0      \N           118.0  [Comedy, Fantasy, Romance]
#
#        averageRating  numVotes
# 3591             6.2      20.0
# 16751            6.4   75327.0

# %% [markdown]
# We divide our "principals" dataset into "cast" (actors and actresses) and the rest.
# The idea is to add to our Movies dataframe two columns: one with a list containing all actors/actresses in the movie, and another including all other crew members who were involved in the movie.

# %%
cast = principals[principals['category'].isin(['actor', 'actress'])]
crew = principals[~principals['category'].isin(['actor', 'actress', 'self'])]

# %%
ordered_cast = pd.DataFrame(cast.groupby(by='tconst').apply(lambda x: [x for x in x['nconst']]))

# %%
ordered_cast = ordered_cast.reset_index().rename(columns={0: 'cast'})

# %%
ordered_cast.head(2)
# Out:
#       tconst                    cast
# 0  tt0000005  [nm0443482, nm0653042]
# 1  tt0000007  [nm0179163, nm0183947]

# %%
# If it went right, we should have no duplicated movies (tconst)
ordered_cast.duplicated('tconst').any()
# Out:
# False

# %%
ordered_crew = pd.DataFrame(crew.groupby(by='tconst').apply(lambda x: [x for x in x['nconst']]))

# %%
ordered_crew = ordered_crew.reset_index().rename(columns={0: 'crew'})

# %%
ordered_crew.head(2)
# Out:
#       tconst                    crew
# 0  tt0000001  [nm0005690, nm0374658]
# 1  tt0000002  [nm0721526, nm1335271]

# %%
# If it went right, we should have no duplicated movies (tconst)
ordered_crew['tconst'].value_counts().max()
# Out:
# 1

# %% [markdown]
# Now we add this information to our movies data.

# %%
movies = pd.merge(movies, ordered_cast, on='tconst', how='left').merge(ordered_crew, on='tconst', how='left')

# %%
# If it went right, we should have no duplicated movies (tconst)
movies.duplicated('tconst').any()
# Out:
# False

# %%
# SANITY CHECK: Back to The Future should have Fox and C. Lloyd within Cast, and Robert Zemeckis within Crew.
movies[movies['tconst']=='tt0088763']
# Out:
#           tconst titleType        primaryTitle       originalTitle  isAdult  \
# 18543  tt0088763     movie  Back to the Future  Back to the Future        0
#
#        startYear endYear  runtimeMinutes                       genres  \
# 18543     1985.0      \N           116.0  [Adventure, Comedy, Sci-Fi]
#
#        averageRating  numVotes                                          cast  \
# 18543            8.5  965811.0  [nm0000150, nm0000502, nm0000670, nm0000417]
#
#                                                     crew
# 18543  [nm0004637, nm0000709, nm0301826, nm0134635, n...

# %% [markdown]
# It worked perfect

# %%
movies['cast'].isna().sum()
# Out:
# 12268

# %%
movies['crew'].isna().sum()
# Out:
# 681

# %% [markdown]
# We do however have some movies with no cast or crew. Let's check a couple.

# %%
movies[movies['cast'].isna()].head(2)
# Out:
#         tconst titleType                      primaryTitle  \
# 53   tt0054050     movie  The Making of the President 1960
# 214  tt0054770     movie                  The Crimebusters
#
#                         originalTitle  isAdult  startYear endYear  \
# 53   The Making of the President 1960        0     1963.0      \N
# 214                  The Crimebusters        0     1962.0      \N
#
#      runtimeMinutes                  genres  averageRating  numVotes cast  \
# 53             90.0  [Documentary, History]            7.3      18.0  NaN
# 214            88.0          [Crime, Drama]            7.3      17.0  NaN
#
#                                                   crew
# 53   [nm0142216, nm0448123, nm0633271, nm0835799, n...
# 214  [nm0818157, nm0725052, nm0300010, nm0683984, n...

# %% [markdown]
# Manually checking these movies, I see that this is indeed the case. These movies have some people involved listed as "self", but nobody listed as actor/actresses. Therefore it makes sense. Let's just fill these movies with 'Unknown' cast/crew.

# %%
movies['cast'].fillna('Unknown', inplace=True)
movies['crew'].fillna('Unknown', inplace=True)

# %% [markdown]
# # Word2Vec

# %% [markdown]
# The idea is to estimate one vector for each person who is involved in a movie. We use the other cast/crew members of a movie as context for the algorithm to learn a vector for a certain person. We need to feed the Word2Vec with a list of sublists in which each of the latter contains the id's of the people involved in each movie. For example, something like:
#
# [nm0000138, nm0000701, nm0000708, nm0000870, nm0365239, nm0000116, nm0484457, nm0000035]

# %%
to_wtv = pd.DataFrame(principals.groupby(by='tconst').apply(lambda x: [x for x in x['nconst']])).reset_index().iloc[:, 1]

# %%
to_wtv.head(3)
# Out:
# 0               [nm1588970, nm0005690, nm0374658]
# 1                          [nm0721526, nm1335271]
# 2    [nm0721526, nm5442194, nm1335271, nm5442200]
# Name: 0, dtype: object

# %% [markdown]
# The following class "Saver" allows us to save the results of the W2V in our disk for future use.

# %%
class Saver(CallbackAny2Vec):
    def __init__(self, data_path):
        self.data_path = data_path
        self.epoch = 1
    
    def on_epoch_end(self, model):
        print(f'Finished epoch {self.epoch}. Saving...')
        output_path = self.data_path / 'w2v_new' / f'epoch_{self.epoch}'
        output_path.parent.mkdir(parents=True, exist_ok=True)
        model.save(str(output_path))
        self.epoch += 1

# %% [markdown]
# Now we build the Word2Vec model, which requires only a couple of lines of code. We use a window of 10, and 100 length vectors will be estimated for each person using the other people involved in each movie as context.

# %%
wtv = Word2Vec(window=10, iter=10, min_count=5, callbacks=[Saver(PATH)])

# %%
wtv.build_vocab(to_wtv)

# %%
wtv.train(to_wtv, total_words=wtv.corpus_total_words, epochs=10)
# Out:
# Finished epoch 1. Saving...
# Finished epoch 2. Saving...
# Finished epoch 3. Saving...
# Finished epoch 4. Saving...
# Finished epoch 5. Saving...
# Finished epoch 6. Saving...
# Finished epoch 7. Saving...
# Finished epoch 8. Saving...
# Finished epoch 9. Saving...
# Finished epoch 10. Saving...
# (362470430, 410851810)

# %% [markdown]
# We can also load the model directly in the future, which is very convenient considering it takes quite a long time.

# %%
PATH = Path('C:/Users/gmanf/OneDrive/Documents/Data Science/Curso ML Practico/ml-practico\data')
class Saver(): pass
wtv = Word2Vec.load(str(PATH / 'w2v_new/epoch_10'))

# %% [markdown]
# # Results from Word2Vec

# %% [markdown]
# The following functions let us turn imdb id's into pictures and names of the cast/crew.

# %%
from IPython.display import HTML, display
from bs4 import BeautifulSoup
import requests
import requests_cache

requests_cache.install_cache('imdb')

def get_name(id):
    response = requests.get(f'https://www.imdb.com/name/{id}/')
    soup = BeautifulSoup(response.content)
    return soup.select('.header .itemprop')[0].text

def get_image(id):
    response = requests.get(f'https://www.imdb.com/name/{id}/')
    soup = BeautifulSoup(response.content)
    candidates = soup.select('#name-poster')
    return candidates[0].attrs['src'] if candidates else 'https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png'

def render_person(id):
    name = get_name(id)
    picture = get_image(id)
    return f"""
    <div style="width: 150px; text-align: center">
        <h4 style='margin-top: -5px'>{name}</h4>
        <div style='font-size:75%; margin-bottom: 5px'>{id}</div>
        <a href="https://www.imdb.com/name/{id}" target="_blank">
            <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="{picture}"/>
        </a>
    </div>
    """

# %%
def show_similars(id, n=10):
    if id in wtv.wv: 
        display(HTML(render_person(id)))
    renders = []
    for similar_id, score in wtv.wv.most_similar(id, topn=n):
        renders.append(render_person(similar_id))
        
    carousel = ''.join(
        [
            f'<div style="margin-left: 10px; float: left">{p}</div>' 
            for p in renders
        ]
        )
    display(HTML(f'<div style="width: 1800px">{carousel}</div>'))

# %%
def show_similars_tovector(id, n=10):
    renders = []
    
    for similar_id, score in wtv.wv.most_similar(id, topn=n):
        renders.append(render_person(similar_id))
        
    carousel = ''.join(
        [
            f'<div style="margin-left: 10px; float: left">{p}</div>' 
            for p in renders
        ]
    )
    display(HTML(f'<div style="width: 1800px">{carousel}</div>'))

# %%
def who_doesnt_match(person1, person2, person3, person4):
    
    p1 = str(person1); p2=str(person2); p3=str(person3); p4=str(person4); 
    result = wtv.wv.doesnt_match([p1, p2, p3, p4])
    
    if result in wtv.wv: 
        display(HTML(render_person(result)))

# %% [markdown]
# Let's check a few similarities

# %%
show_similars('nm0000138')
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Leonardo DiCaprio</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000138</div>
#         <a href="https://www.imdb.com/name/nm0000138" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMjI0MTg3MzI0M15BMl5BanBnXkFtZTcwMzQyODU2Mw@@._V1_UY317_CR10,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Angelina Jolie</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0001401</div>
#         <a href="https://www.imdb.com/name/nm0001401" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BODg3MzYwMjE4N15BMl5BanBnXkFtZTcwMjU5NzAzNw@@._V1_UY317_CR22,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Brad Pitt</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000093</div>
#         <a href="https://www.imdb.com/name/nm0000093" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMjA1MjE2MTQ2MV5BMl5BanBnXkFtZTcwMjE5MDY0Nw@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jennifer Connelly</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000124</div>
#         <a href="https://www.imdb.com/name/nm0000124" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BOTczNTgzODYyMF5BMl5BanBnXkFtZTcwNjk4ODk4Mw@@._V1_UY317_CR12,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Matt Damon</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000354</div>
#         <a href="https://www.imdb.com/name/nm0000354" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTM0NzYzNDgxMl5BMl5BanBnXkFtZTcwMDg2MTMyMw@@._V1_UY317_CR11,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Tom Cruise</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000129</div>
#         <a href="https://www.imdb.com/name/nm0000129" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTk1MjM3NTU5M15BMl5BanBnXkFtZTcwMTMyMjAyMg@@._V1_UY317_CR14,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jennifer Davisson</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm2248832</div>
#         <a href="https://www.imdb.com/name/nm2248832" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Ben Affleck</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000255</div>
#         <a href="https://www.imdb.com/name/nm0000255" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTI4MzIxMTk0Nl5BMl5BanBnXkFtZTcwOTU5NjA0Mg@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Edward Norton</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0001570</div>
#         <a href="https://www.imdb.com/name/nm0001570" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTYwNjQ5MTI1NF5BMl5BanBnXkFtZTcwMzU5MTI2Mw@@._V1_UY317_CR16,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Casey Affleck</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000729</div>
#         <a href="https://www.imdb.com/name/nm0000729" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTY3Nzc0MDg1OF5BMl5BanBnXkFtZTgwMzk5OTk2OTE@._V1_UY317_CR129,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jerry Bruckheimer</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000988</div>
#         <a href="https://www.imdb.com/name/nm0000988" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMjExNDIwNTA5M15BMl5BanBnXkFtZTcwMDg3NTU2Mw@@._V1_UY317_CR12,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div></div>

# %%
show_similars('nm0000264')
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Pedro Almodóvar</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000264</div>
#         <a href="https://www.imdb.com/name/nm0000264" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMGM2NTk2MDEtN2Y4Ni00YzNjLWE1NDQtMWM4MjJlZWI1NmU2XkEyXkFqcGdeQXVyMDc2NTEzMw@@._V1_UY317_CR12,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Javier Bardem</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000849</div>
#         <a href="https://www.imdb.com/name/nm0000849" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTY1NTc4NTYzMF5BMl5BanBnXkFtZTcwNDIwOTY1NA@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Penélope Cruz</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0004851</div>
#         <a href="https://www.imdb.com/name/nm0004851" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTM0Mzc1MTc2OF5BMl5BanBnXkFtZTcwMzE4MzQxMw@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Agustín Almodóvar</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0021948</div>
#         <a href="https://www.imdb.com/name/nm0021948" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BNWJiN2VmNjgtODMwYS00MzI1LTg3OGUtZDBmZWRkNmJkYzI3XkEyXkFqcGdeQXVyMjUyNDk2ODc@._V1_UY317_CR150,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>César Abeytua</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm1231267</div>
#         <a href="https://www.imdb.com/name/nm1231267" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Alejandro Amenábar</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0024622</div>
#         <a href="https://www.imdb.com/name/nm0024622" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTY3NzEwMzU3NF5BMl5BanBnXkFtZTYwNTA5NTMz._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Paloma Chamorro</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm1419748</div>
#         <a href="https://www.imdb.com/name/nm1419748" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BNzEyY2FmOWYtZTlhNy00ZTUxLThmMzQtZTg3MDI1NjYwNGQxXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Manel Domínguez</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm3256947</div>
#         <a href="https://www.imdb.com/name/nm3256947" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Antonio Banderas</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000104</div>
#         <a href="https://www.imdb.com/name/nm0000104" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTUyOTQ3NTYyNF5BMl5BanBnXkFtZTcwMTY2NjIzNQ@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Manuel Palacios</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0657263</div>
#         <a href="https://www.imdb.com/name/nm0657263" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Eliades Ochoa</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0643733</div>
#         <a href="https://www.imdb.com/name/nm0643733" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BOTE3MjgyOTctY2ViOS00YjE5LWEwOGYtYTgwZTQ5MTE3NWUyXkEyXkFqcGdeQXVyNDg2MjUxNjM@._V1_UY317_CR131,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div></div>

# %%
show_similars('nm0000158')
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Tom Hanks</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000158</div>
#         <a href="https://www.imdb.com/name/nm0000158" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTQ2MjMwNDA3Nl5BMl5BanBnXkFtZTcwMTA2NDY3NQ@@._V1_UY317_CR2,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Brian Grazer</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0004976</div>
#         <a href="https://www.imdb.com/name/nm0004976" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTI4MTk2NTU3NV5BMl5BanBnXkFtZTcwMDY0OTA1Mg@@._V1_UY317_CR3,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Meryl Streep</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000658</div>
#         <a href="https://www.imdb.com/name/nm0000658" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTU4Mjk5MDExOF5BMl5BanBnXkFtZTcwOTU1MTMyMw@@._V1_UY317_CR6,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jerry Bruckheimer</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000988</div>
#         <a href="https://www.imdb.com/name/nm0000988" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMjExNDIwNTA5M15BMl5BanBnXkFtZTcwMDg3NTU2Mw@@._V1_UY317_CR12,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Steven Spielberg</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000229</div>
#         <a href="https://www.imdb.com/name/nm0000229" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTY1NjAzNzE1MV5BMl5BanBnXkFtZTYwNTk0ODc0._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Gary Goetzman</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0324556</div>
#         <a href="https://www.imdb.com/name/nm0324556" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTY2NTYzNTAxOV5BMl5BanBnXkFtZTcwODk1NDY3NQ@@._V1_UY317_CR7,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Frank Marshall</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0550881</div>
#         <a href="https://www.imdb.com/name/nm0550881" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTI0Mzg1ODQzMV5BMl5BanBnXkFtZTYwNDk1NDY0._V1_UY317_CR7,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>John Underkoffler</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm1119908</div>
#         <a href="https://www.imdb.com/name/nm1119908" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTc4Njg0MDQ1N15BMl5BanBnXkFtZTYwOTI4NTky._V1_UY317_CR51,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Sara Bernstein</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0077136</div>
#         <a href="https://www.imdb.com/name/nm0077136" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Tommy Lee Jones</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000169</div>
#         <a href="https://www.imdb.com/name/nm0000169" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTkyNjc4MDc0OV5BMl5BanBnXkFtZTcwOTc5OTUwOQ@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Woody Harrelson</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000437</div>
#         <a href="https://www.imdb.com/name/nm0000437" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTU3NDc2ODc4MF5BMl5BanBnXkFtZTcwODk2MzAyMg@@._V1_UY317_CR1,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div></div>

# %% [markdown]
# Nice to see that results seem mostly to make a lot of sense :)
#
# Now let's search for a random unkwnown actor. If the W2V representations make sense, we should get other relatively unknown cast/crew.

# %%
show_similars('nm4446286')
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Montgomery Markland</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4446286</div>
#         <a href="https://www.imdb.com/name/nm4446286" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZTNjOTRhYjUtYTM3Ny00YTFmLWFhODItNjMyYTM3MDlhOWM2XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_.jpg"/>
#         </a>
#     </div>
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Ryan Shoos</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4090362</div>
#         <a href="https://www.imdb.com/name/nm4090362" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZDlkYzlhMDQtMDI1Ni00NzZlLTk0YzQtMGI2ODk3YzhiOWFkXkEyXkFqcGdeQXVyMjMxMDQ2NTA@._V1_UY317_CR2,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Brandon Ruiter</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4464348</div>
#         <a href="https://www.imdb.com/name/nm4464348" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTQxMmQ3NTMtMDE2MC00OTIzLWFiZmUtYTY1ZmUxNjJmOGI1XkEyXkFqcGdeQXVyMzU5OTY4NDQ@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Maggie Mahrt</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm3793405</div>
#         <a href="https://www.imdb.com/name/nm3793405" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BNDFiYjY2NmMtZmJkYi00NDZjLWEzNjUtNTc2MzIxZDJjYzYxXkEyXkFqcGdeQXVyMjM1NzA4MzA@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Diana Chiritescu</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm3840073</div>
#         <a href="https://www.imdb.com/name/nm3840073" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZTM3YmZkMzItYWI1MS00MzBjLWIwMzYtNTJmNDgzMzdjZjY0XkEyXkFqcGdeQXVyMjM0OTQ3MzE@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Cameron Chambers</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4285715</div>
#         <a href="https://www.imdb.com/name/nm4285715" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZGY0OTdhODMtYmE2Zi00ZDk4LWFiMzktNjIzMTg0NjUzOTY2XkEyXkFqcGdeQXVyMjQ5NDEzODc@._V1_UY317_CR131,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Dennis Ruel</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm2372966</div>
#         <a href="https://www.imdb.com/name/nm2372966" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTQ1ODE0NTU1MF5BMl5BanBnXkFtZTgwMjY3NDQ5NjE@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Thom Rivera</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm1115076</div>
#         <a href="https://www.imdb.com/name/nm1115076" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BODkxMTYyYzktYzllNi00NTgyLWFkMDItNjhlMWI1ZDQxNGMwXkEyXkFqcGdeQXVyMDc3NTUyOQ@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>David Carey Foster</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm1132269</div>
#         <a href="https://www.imdb.com/name/nm1132269" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMDk5ZjRlNTMtYjljNy00ZTZmLWJmMWMtM2Q2OTNhNjg5MTg3XkEyXkFqcGdeQXVyMzM4MzkzNA@@._V1_UY317_CR20,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jon Snow</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4643289</div>
#         <a href="https://www.imdb.com/name/nm4643289" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZTZiOThhNGQtM2U1MC00NDY1LWIzOTctZDYwN2U3MGQwZmExXkEyXkFqcGdeQXVyNDcyMTA5MjE@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Christine McAuliffe</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm3267517</div>
#         <a href="https://www.imdb.com/name/nm3267517" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMjVjZDA0YjktMmM2OC00NDRiLTk1NWItNzQwYzAyMmVhNmNiXkEyXkFqcGdeQXVyNjU3NjQ3NDI@._V1_UY317_CR15,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div></div>

# %% [markdown]
# Indeed, we get a bunch of random unknown people (at least to me), just as we hoped. One of them is actually called Jon Snow, which I find pretty funny.

# %% [markdown]
# Of course looking at the vectors themselves make little sense to us humans. But they do appear to make sense to a computer, which is what makes this technique so interesting.
# Here's for example how Di Caprio's vector looks like:

# %%
wtv.wv['nm0000138']
# Out:
# array([-0.10366471,  0.46839067, -1.2206813 ,  0.3002078 ,  0.178207  ,
#         1.6990376 , -0.46968842, -0.0759187 ,  0.83627015, -0.4428964 ,
#         0.12417804,  0.20482583, -0.60909355, -1.7934252 , -0.52148175,
#         0.34832796,  0.5963028 ,  0.24976212, -1.61199   ,  1.5369637 ,
#        -0.09164323, -1.0604653 ,  0.22418326,  0.22463627, -0.36901665,
#         1.0456139 ,  1.5883263 , -0.46983522, -0.78857243,  0.32545882,
#         0.84453577, -1.0661434 ,  0.7003741 , -0.9967633 ,  2.341712  ,
#         0.20226601,  0.7291691 , -0.27283406,  0.775425  , -0.7664714 ,
#        -0.75261563,  0.2583464 ,  0.20865093, -0.2554017 , -0.25745627,
#        -1.239082  ,  1.2924539 , -1.1842724 ,  0.05884712,  0.04236272,
#         0.222534  , -2.4201686 , -0.21548343, -0.6565128 , -0.9076947 ,
#         0.775961  , -0.859882  , -0.0978079 ,  0.4925904 , -2.4760904 ,
#         1.3713    , -0.19479962,  1.2384449 , -0.38421512,  1.0798846 ,
#         0.84606755, -0.9600651 , -0.44379333, -0.83380246,  1.9110711 ,
#        -0.25485674, -0.19784024, -0.2910676 ,  0.45145392,  0.10209139,
#        -1.2609437 ,  0.08785842, -0.12817742,  1.3819135 , -1.4173417 ,
#         1.2179363 ,  1.1433995 , -2.7761066 ,  0.41355214,  1.5711852 ,
#         0.3093246 ,  1.5140924 , -0.80746865,  0.03201788,  1.7863638 ,
#         0.12311792, -0.89726394, -0.44981098, -1.168564  ,  1.1349422 ,
#        -0.95103186, -0.12969138, -0.10300206,  0.28001672, -1.4945205 ],
#       dtype=float32)

# %% [markdown]
# Let's play a bit more. W2V has a method called "doesn't match" that returns which element from a list is the one that does not belong in the group. More technically, it computes the center of the group (the mean of all vectors) and then returns the one who is furthest away from this center.
#
# I think this is a great way to check which parts of the cast spectrum are covered by these vectors.
#
# Let's start by checking whether how "famous" the actors are is covered. We have seen already from the previous examples that this indeed seems to be covered.

# %% [markdown]
# Fame Checking: I take 3 famous actors/actresses and 1 random. The random one should be the one who doesn't match.

# %%
brad_pitt = 'nm0000093'
ben_affleck = 'nm0000255'
edward_norton = 'nm0001570'

# %%
import random
random_person = random.sample(list(principals.nconst.unique()), 1)[0]

# %%
random_person
# Out:
# 'nm4686226'

# %%
who_doesnt_match(edward_norton, ben_affleck, brad_pitt, random_person)
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Ursula B. Kannegießer</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4686226</div>
#         <a href="https://www.imdb.com/name/nm4686226" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>

# %% [markdown]
# Indeed, we get the random person.
#
# Now we'll try it the other way and use three random actors/actresses and one famous actress, who should be the one that does not belong if our model is capturing "fame" right.

# %%
angelina_jolie= 'nm0001401'
random1 = random.sample(list(principals.nconst.unique()), 1)[0]
random2 = random.sample(list(principals.nconst.unique()), 1)[0]
random3 = random.sample(list(principals.nconst.unique()), 1)[0]

# %%
print(random1, random2, random3)
# Out:
# nm8591246 nm7981642 nm1940999

# %%
who_doesnt_match(angelina_jolie, random1, random2, random3)
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Angelina Jolie</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0001401</div>
#         <a href="https://www.imdb.com/name/nm0001401" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BODg3MzYwMjE4N15BMl5BanBnXkFtZTcwMjU5NzAzNw@@._V1_UY317_CR22,0,214,317_AL_.jpg"/>
#         </a>
#     </div>

# %% [markdown]
# Age Checking: I take 3 kind of new young stars and one star from the past. Despite being all famous, let's see if the model can differentiate according to which era they belong to.

# %%
paul_newman = 'nm0000056'
joseph_gordon_levitt = 'nm0330687'
jennifer_lawrence = 'nm2225369'
rooney_mara = 'nm1913734'

# %%
who_doesnt_match(paul_newman, joseph_gordon_levitt, jennifer_lawrence, rooney_mara)
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Paul Newman</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000056</div>
#         <a href="https://www.imdb.com/name/nm0000056" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BODUwMDYwNDg3N15BMl5BanBnXkFtZTcwODEzNTgxMw@@._V1_UY317_CR22,0,214,317_AL_.jpg"/>
#         </a>
#     </div>

# %% [markdown]
# Again we see it works pretty well.

# %% [markdown]
# To end with, let's see if the models also picks up which kind of genres the actor/actress is usually in. I'll include three (mostly) comedy actors and one more serious-type actor such as Christian Bale, who should not belong here.

# %%
christian_bale = 'nm0000288'
will_ferrell = 'nm0002071'
seth_rogen = 'nm0736622'
adam_sandler = 'nm0001191'

# %%
who_doesnt_match(christian_bale, will_ferrell, kevin_hart, adam_sandler)
# Out:
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Christian Bale</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm0000288</div>
#         <a href="https://www.imdb.com/name/nm0000288" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMTkxMzk4MjQ4MF5BMl5BanBnXkFtZTcwMzExODQxOA@@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>

# %% [markdown]
# We could keep trying things endlessly but let's end for now.
#
# In summary, we have seen that using word2vec to embedd actors into vectors seem to work pretty well. It looks like these numbers contain information such as how famous the actor/actress is, in which decade he/she worked the most, and the kind of movies he/she is usually in.
#
# Remember that these vectors were assembled by looking at who worked with whom across all movies in our data. So it seems that you can describe an actor/actress pretty well by knowing who he/she has worked with in the past!

# %% [markdown]
# Now we should decide what vector to estimate for cast/crew that do not have a vector (because they did not appear in a sufficient minimum number of movies).
# I consider two obvious options:
#
# 1- We take the np.mean vector of all people.
#
# 2- We use a vector full of zeros.
#
# Let's see who are the most similar people to each of these two default vectors:

# %%
default_vector = np.mean(wtv.wv.vectors, axis=0)

# %%
show_similars_tovector([default_vector])
# Out:
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Deepak Sharma</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10594694</div>
#         <a href="https://www.imdb.com/name/nm10594694" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Kôichi Makaino</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm6231590</div>
#         <a href="https://www.imdb.com/name/nm6231590" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Mary Gacheri</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm6638101</div>
#         <a href="https://www.imdb.com/name/nm6638101" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Charles Ouda</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10758812</div>
#         <a href="https://www.imdb.com/name/nm10758812" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jackline Kabugi</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm7961922</div>
#         <a href="https://www.imdb.com/name/nm7961922" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Kamal Tewari</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10594695</div>
#         <a href="https://www.imdb.com/name/nm10594695" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>George Ohawa</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm5051298</div>
#         <a href="https://www.imdb.com/name/nm5051298" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>June Akinyi</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10758813</div>
#         <a href="https://www.imdb.com/name/nm10758813" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Yûko Arakawa</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm6231597</div>
#         <a href="https://www.imdb.com/name/nm6231597" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Anil Bass</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10924624</div>
#         <a href="https://www.imdb.com/name/nm10924624" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div></div>

# %%
default_vector = np.zeros(100)

# %%
show_similars_tovector([default_vector])
# Out:
# <div style="width: 1800px"><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Jackelyn Viera Iloff</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm9968911</div>
#         <a href="https://www.imdb.com/name/nm9968911" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BMzBkOTU2YTUtMzE0ZC00MzY4LWJjYmEtMzM5NjU1YmRmM2FlXkEyXkFqcGdeQXVyMTAzOTU5NjEz._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Andi Horvath</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm2610429</div>
#         <a href="https://www.imdb.com/name/nm2610429" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Joshua Turpin</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm5640051</div>
#         <a href="https://www.imdb.com/name/nm5640051" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Reuben J. Rogak</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4999958</div>
#         <a href="https://www.imdb.com/name/nm4999958" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Julia Hart</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm6880790</div>
#         <a href="https://www.imdb.com/name/nm6880790" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Atul Sharma</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4222421</div>
#         <a href="https://www.imdb.com/name/nm4222421" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BZjhhYTQxMTgtNGUxNS00NjlhLWEyNzktNjIzZjdjZDJhN2UxXkEyXkFqcGdeQXVyMDkwNTkwNg@@._V1_UY317_CR55,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Alex Dwiar</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm4002529</div>
#         <a href="https://www.imdb.com/name/nm4002529" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Omer Aubin</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm10408473</div>
#         <a href="https://www.imdb.com/name/nm10408473" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Orlando Bryant</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm9620910</div>
#         <a href="https://www.imdb.com/name/nm9620910" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png"/>
#         </a>
#     </div>
#     </div><div style="margin-left: 10px; float: left">
#     <div style="width: 150px; text-align: center">
#         <h4 style='margin-top: -5px'>Shorni Hardy</h4>
#         <div style='font-size:75%; margin-bottom: 5px'>nm5930152</div>
#         <a href="https://www.imdb.com/name/nm5930152" target="_blank">
#             <img style="width: 100px; display: block; margin-left: auto; margin-right: auto;" src="https://m.media-amazon.com/images/M/MV5BNGMyYWQxMGUtYjhiYS00YmIwLTg4ODQtYzUzZWRhYmE5MDQ0XkEyXkFqcGdeQXVyODQ5NzI3NTM@._V1_UX214_CR0,0,214,317_AL_.jpg"/>
#         </a>
#     </div>
#     </div></div>

# %% [markdown]
# In both cases we get kind of obscure people, which is exactly what we would expect. Not sure what to decide here. For now let's use the np.zeros vector and later we check if we do better the other way.

# %% [markdown]
# # Choosing proxy for movies' popularity

# %% [markdown]
# I will use the number of IMDB votes as a proxy to measure a movie's popularity.
#
# The goal will be to predict which movies will be among the Top 1% in terms of IMDB votes ( > ~125,000 votes) based on its cast and crew.
#
# We'll call these kinds of movies a "Classic" in our dataset to easily differentiate them from the rest.

# %%
np.percentile(movies.numVotes, 99)
# Out:
# 123586.37999999936

# %%
movies_docs = movies.to_dict(orient='records')
movies['Classic'] = [1 if x['numVotes']>np.percentile(movies.numVotes, 99) else 0 for x in movies_docs]

# %%
len(movies[movies['Classic']==1]) / len(movies)
# Out:
# 0.01000508240760909

# %% [markdown]
# Let's see which are some of these "classic" movies we have.

# %%
movies.sort_values('Classic', ascending=False).head(5)
# Out:
#           tconst titleType          primaryTitle         originalTitle  \
# 58051  tt0347149     movie  Howl's Moving Castle  Hauru no ugoku shiro
# 27312  tt0107362     movie      Last Action Hero      Last Action Hero
# 88064  tt1605630     movie      American Reunion      American Reunion
# 55004  tt0307901     movie             25th Hour             25th Hour
# 65446  tt0443706     movie                Zodiac                Zodiac
#
#        isAdult  startYear endYear  runtimeMinutes  \
# 58051        0     2004.0      \N           119.0
# 27312        0     1993.0      \N           130.0
# 88064        0     2012.0      \N           113.0
# 55004        0     2002.0      \N           135.0
# 65446        0     2007.0      \N           157.0
#
#                                genres  averageRating  numVotes  \
# 58051  [Adventure, Animation, Family]            8.2  291644.0
# 27312     [Action, Adventure, Comedy]            6.4  128493.0
# 88064                        [Comedy]            6.7  194770.0
# 55004                         [Drama]            7.6  164153.0
# 65446         [Crime, Drama, Mystery]            7.7  407237.0
#
#                                                cast  \
# 58051  [nm0047962, nm0454120, nm0309107, nm0594271]
# 27312  [nm0000216, nm0000719, nm0138770, nm0001097]
# 88064  [nm0004755, nm0004989, nm0005405, nm0005098]
# 55004  [nm0001570, nm0001608, nm0000450, nm0206257]
# 65446  [nm0350453, nm0000375, nm0749263, nm0000381]
#
#                                                     crew  Classic
# 58051  [nm0386749, nm0594503, nm1168510, nm0218760, n...        1
# 27312  [nm0745030, nm0001532, nm0672015, nm0498963, n...        1
# 88064  [nm0956015, nm1375358, nm1376383, nm0381221, n...        1
# 55004  [nm0005966, nm0000490, nm1125275, nm0153892, n...        1
# 65446  [nm0005219, nm0000399, nm0888743, nm1172196, n...        1

# %% [markdown]
# Maybe not all of these movies can really be considered actual "classics", but they do have a very large number of votes and are truly famous movies.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Cast & Crew

# %% [markdown]
# The class below takes, for each movie, its entire cast or crew vectors, and then computes the mean of all of them.
#
# The result of this will be one 100-length vector that summarizes the cast or crew that was involved in the movie.

# %%
class W2VFeatures(BaseEstimator, TransformerMixin):
    def __init__(self, wtv, category, min_cnt_movies=2):
        self.category = category
        self.min_cnt_movies = min_cnt_movies
        self.wtv = wtv
        self.default_vector = default_vector

    def fit(self, X, y):
        self.default_vector = np.zeros(100)
        #self.default_vector = np.mean(wtv.wv.vectors, axis=0)
        return self
    
    def _get_movie_vector(self, x_i):
        vectors = []
        for person in x_i[self.category]:
            if person not in self.wtv.wv or self.wtv.wv.vocab[person].count < self.min_cnt_movies: continue
            vectors.append(self.wtv.wv[person])
            
        if len(vectors) == 0:
            return self.default_vector
        else:
            return np.mean(vectors, axis=0)
            
    def transform(self, X):
        return np.asarray([self._get_movie_vector(x_i) for x_i in X])

# %% [markdown]
# ### Other features

# %% [markdown]
# There may be some other things, like the Genre of a movie, its Runtime and the Year it was released, that affect the number of votes it gets. For this reason, it is better to include these control variables in order to better understand the effect that the cast has on the movie's popularity.

# %% [markdown]
# ### RunTime

# %%
movies.runtimeMinutes.corr(np.log(movies.numVotes))
# Out:
# 0.23239350554642257

# %% [markdown]
# We see that there is a weak/moderate correlation between runtime and the number of votes, even though I really doubt this relation is linear (which is what the coefficient above measures). Anyway, looks like we should add RunTime to our model.

# %%
class RunTime(BaseEstimator, TransformerMixin):
    def fit(self, X, y): return self
    def transform(self, X):
        res = []
        for e in X:
            res.append({'runTime': int(e['runtimeMinutes'])})
        return res

# %% [markdown]
# ### Genre

# %% [markdown]
# First let's see how balanced/imbalanced the genres are in our data according to whether they are "classic" movies:

# %%
class GenreDummies(BaseEstimator, TransformerMixin):
    def fit(self, X, y): return self
    def transform(self, X):
        res = []
        for e in X:
            res.append({g: 1 for g in e['genres']})
        return res

# %%
v = DictVectorizer(sparse=False)

# %%
dummies_genre = v.fit_transform(GenreDummies().transform(movies_docs))

# %%
df_genres = pd.DataFrame(dummies_genre, columns=v.feature_names_)
df_genres = df_genres.astype(int)
genres_analysis = pd.concat([movies, df_genres], axis=1)

# %%
graph1 = pd.DataFrame(genres_analysis[genres_analysis['numVotes'] > np.percentile(genres_analysis.numVotes,97)].iloc[:,14:-1] \
                     .sum(axis=0) / len(genres_analysis[genres_analysis['numVotes'] > \
                    np.percentile(genres_analysis.numVotes,97)])).reset_index().rename(columns={'index': 'genre', 0: 'pct'})
graph1['classic']="Classic"

# %%
graph2 = pd.DataFrame(genres_analysis.iloc[:,14:-1] \
                     .sum(axis=0) / len(genres_analysis)).reset_index().rename(columns={'index': 'genre', 0: 'pct'})
graph2['classic'] = "All"

# %%
graph = pd.concat([graph1, graph2], axis=0)

# %%
import seaborn as sns
sns.set_style("white")
fig, ax = plt.subplots(figsize=(14,20))
ax = sns.barplot(y='genre', x='pct', hue='classic', data=graph, palette='viridis')
ax.grid(color='grey', linestyle='-', linewidth=0.1, axis='x')
ax.set_xticks([0.05, 0.10, .15, .20, .25, .30, .35, .40, .45, .50])
ax.set_yticklabels(graph.genre[:23], size = 13, fontfamily='serif')
ax.set_xlabel('% of total movies', fontsize=15)
ax.set_ylabel('Genre', fontsize=15, fontfamily='serif')
ax.tick_params(labelbottom=True,labeltop=True)
plt.title('% of total movies per genre (1960-2020)', fontsize=20)
# Out:
# Text(0.5, 1.0, '% of total movies per genre (1960-2020)')

# %% [markdown]
# We find some very clear differences, mostly in the genres Action and Adventure.
#
# We see that Action movies comprise around 12% of total movies, but 30% of these so-called "classic" movies belong to the Action genre. We find a similar situation with the Adventure genre movies. This suggests that we must control for a movie's genre in the model.
#
# Let's see now how certain genres' popularity has evolved through time.

# %%
genres_prog = genres_analysis.groupby(by='startYear').agg({'Horror': 'sum', 'Comedy': 'sum', \
                                                           'Drama':'sum', 'Sci-Fi':'sum', 'tconst': 'count'})

# %%
genres_prog.reset_index(inplace=True)
genres_prog['%_horror'] = genres_prog['Horror'] / genres_prog['tconst'] * 100
genres_prog['%_comedy'] = genres_prog['Comedy'] / genres_prog['tconst'] * 100
genres_prog['%_drama'] = genres_prog['Drama'] / genres_prog['tconst'] * 100
genres_prog['%_scifi'] = genres_prog['Sci-Fi'] / genres_prog['tconst'] * 100
genres_prog = genres_prog.iloc[:-1,:]

# %%
ax = plt.subplots(figsize=(18,8))
ax = sns.lineplot(x=genres_prog['startYear'], y=genres_prog['%_horror'], legend='brief')
ax.set_xlabel('Year', fontsize=15)
ax.set_ylabel('# of Horror films per 100 movies', fontsize=15)
ax.grid(color='grey', linestyle='-', linewidth=0.1)
ax.set_xticks([1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020])
plt.title('Progression of Horror films through time', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Progression of Horror films through time')

# %% [markdown]
# We see that the production of Horror films decreased heavily during the 90's after the golden age of the genre in the 80's. It then started slowly increasing again after year 2000.

# %%
ax = plt.subplots(figsize=(18,8))
ax = sns.lineplot(x=genres_prog['startYear'], y=genres_prog['%_scifi'], legend='brief')
ax.set_xlabel('Year', fontsize=15)
ax.set_ylabel('# of Sci-Fi films per 100 movies', fontsize=15)
ax.grid(color='grey', linestyle='-', linewidth=0.1)
ax.set_xticks([1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020])
plt.title('Progression of Sci-Fi films through time', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Progression of Sci-Fi films through time')

# %% [markdown]
# ### Year of Release

# %%
class ReleaseYear(BaseEstimator, TransformerMixin):
    def fit(self, X, y): return self
    def transform(self, X):
        res = []
        for e in X:
            res.append({'release_year': int(e['startYear'])})
        return res

# %%
ax = plt.subplots(figsize=(18,8))
ax = sns.lineplot(x=movies['startYear'], y=np.log(movies['numVotes']))
ax.grid(color='grey', linestyle='-', linewidth=0.1)
plt.title('Year vs. logVotes')
# Out:
# Text(0.5, 1.0, 'Year vs. logVotes')

# %% [markdown]
# We see that the number of votes increases until the beginning of the 00's and then slowly goes down. It seems to make sense to control for Year of Release of the movies.

# %% [markdown]
# # Train/Test Split

# %% [markdown]
# I'll use only movies after 1980 for training to reduce our data a bit and the needed computation power.
#
# To achieve a more realistic predictive scenario, I'll use movies from 1980-2016 for training, and movies from 2017-2020 for testing.

# %%
train_df = movies[movies.startYear.isin(range(1975,2016))]
test_df = movies[movies.startYear.isin(range(2016,2020))]
len(train_df), len(test_df), len(test_df) / len(train_df)
# Out:
# (100330, 21305, 0.21234924748330508)

# %%
print(len(train_df[train_df['Classic']==1]) / len(train_df))
print(len(test_df[test_df['Classic']==1]) / len(test_df))
# Out:
# 0.012020332901425297
# 0.006618164750058672

# %% [markdown]
# We have 1.25% of positive examples in our training set, and only 0.6% in our testing set. This is not ideal, but I still prefer to train on older movies and test on more recent ones, as it is a more useful scenario in practical terms, so I'll keep it this way.

# %%
train_docs = train_df.to_dict(orient='records')
test_docs = test_df.to_dict(orient='records')

# %%
y_train = (train_df.Classic).values
y_test = (test_df.Classic).values

# %% [markdown]
# # Predictive Model

# %%
def test_pipe(pipe):
    return {
        'train_auc': roc_auc_score(y_train, pipe.predict_proba(train_docs)[:, 1]),
        'test_auc': roc_auc_score(y_test, pipe.predict_proba(test_docs)[:, 1]),
        'f1':f1_score(y_test, pipe.predict(test_docs)),
        'precision':precision_score(y_test, pipe.predict(test_docs)),
        'recall':recall_score(y_test, pipe.predict(test_docs)),
        'f_05_score': fbeta_score(y_test, pipe.predict(test_docs), beta=0.5)
    }

# %%
def see_preds(pipe):
    preds = pipe.predict_proba(test_docs)
    vis = test_df[['tconst','primaryTitle','startYear','runtimeMinutes','genres','numVotes','averageRating', 'Classic'\
                  ]]
    vis['prob_True'] = [preds[i][1] for i in range(len(preds))]
    return vis

# %%
def get_features_pipe():
    steps = []
    steps.append(make_pipeline(W2VFeatures(wtv, category='cast', min_cnt_movies=3)))
    steps.append(make_pipeline(W2VFeatures(wtv, category='crew', min_cnt_movies=3)))
    steps.append(make_pipeline(RunTime(), DictVectorizer(sparse=False)))
    steps.append(make_pipeline(GenreDummies(), DictVectorizer(sparse=False)))
    steps.append(make_pipeline(ReleaseYear(), DictVectorizer(sparse=False)))
    res = make_union(*steps)
    return res

def get_model_pipe(features_pipe, scaler, estimator):
    return make_pipeline(features_pipe, scaler, estimator)

# %%
features_pipe=get_features_pipe()

# %%
model = get_model_pipe(
                        features_pipe,
                        scaler = StandardScaler(), 
                        estimator= LogisticRegression(max_iter=400
                                                     ),
                                             )
model.fit(train_docs, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('featureunion',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('pipeline-1',
#                                                  Pipeline(memory=None,
#                                                           steps=[('w2vfeatures',
#                                                                   W2VFeatures(category='cast',
#                                                                               min_cnt_movies=3,
#                                                                               wtv=<gensim.models.word2vec.Word2Vec object at 0x0000023D40F37508>))],
#                                                           verbose=False)),
#                                                 ('pipeline-2',
#                                                  Pipeline(memory=None,
#                                                           steps=[('w2vfeatures',
#                                                                   W2VFeatures(category=...
#                               transformer_weights=None, verbose=False)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=400,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
test_pipe(model)
# Out:
# {'train_auc': 0.9870916910410487,
#  'test_auc': 0.9919490610979973,
#  'f1': 0.5562913907284768,
#  'precision': 0.5217391304347826,
#  'recall': 0.5957446808510638,
#  'f_05_score': 0.535031847133758}

# %%
test_pipe(model)
# Out:
# {'train_auc': 0.9870916910410487,
#  'test_auc': 0.9919490610979973,
#  'f1': 0.5562913907284768,
#  'precision': 0.5217391304347826,
#  'recall': 0.5957446808510638,
#  'f_05_score': 0.535031847133758}

# %% [markdown]
# We get an outstanding ROC AUC score of 98% in our testing set.
#
# We have a precision of 59% and a Recall of 60%, both very good values considering that only 0.6% of the examples in the testing set are positive. So there are very few movies that got this number of votes in our test data, but we can correctly identify more than 60% of them with our simple Logistic Regression model.

# %% [markdown]
# Let's see some of the predictions to get a more practical feel for what our model is predicting:

# %%
see_preds(model).sort_values(by='numVotes', ascending=False).head(10)
# Out:
# C:\Users\gmanf\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#            tconst                             primaryTitle  startYear  \
# 138759  tt7286456                                    Joker     2019.0
# 121178  tt4154756                   Avengers: Infinity War     2018.0
# 121179  tt4154796                        Avengers: Endgame     2019.0
# 114695  tt3315342                                    Logan     2017.0
# 97133   tt1825683                            Black Panther     2018.0
# 116201  tt3501632                           Thor: Ragnarok     2017.0
# 119415  tt3896198           Guardians of the Galaxy Vol. 2     2017.0
# 108405  tt2527336  Star Wars: Episode VIII - The Last Jedi     2017.0
# 67673   tt0451279                             Wonder Woman     2017.0
# 126516  tt5013056                                  Dunkirk     2017.0
#
#         runtimeMinutes                        genres  numVotes  averageRating  \
# 138759           122.0      [Crime, Drama, Thriller]  859693.0            8.5
# 121178           149.0   [Action, Adventure, Sci-Fi]  798155.0            8.4
# 121179           181.0    [Action, Adventure, Drama]  757686.0            8.4
# 114695           137.0       [Action, Drama, Sci-Fi]  628395.0            8.1
# 97133            134.0   [Action, Adventure, Sci-Fi]  600365.0            7.3
# 116201           130.0   [Action, Adventure, Comedy]  565421.0            7.9
# 119415           136.0   [Action, Adventure, Comedy]  551012.0            7.6
# 108405           152.0  [Action, Adventure, Fantasy]  548345.0            7.0
# 67673            141.0  [Action, Adventure, Fantasy]  536725.0            7.4
# 126516           106.0      [Action, Drama, History]  533142.0            7.9
#
#         Classic  prob_True
# 138759        1   0.712115
# 121178        1   0.999856
# 121179        1   0.999871
# 114695        1   0.721812
# 97133         1   0.995712
# 116201        1   0.993042
# 119415        1   0.919142
# 108405        1   0.968856
# 67673         1   0.643241
# 126516        1   0.041303

# %% [markdown]
# The movies above are the ones with the highest number of votes in the test data. Our model correctly identified all of them as movies that would get >125,000 votes, except for Dunkirk, in which case it failed badly to recognize it as a future Classic.

# %% [markdown]
# To better understand what our W2V Cast vectors are doing, let's see how well we would do without the Word2Vec features.

# %%
def get_features_pipe():
    steps = []
    steps.append(make_pipeline(RunTime(), DictVectorizer(sparse=False)))
    steps.append(make_pipeline(GenreDummies(), DictVectorizer(sparse=False)))
    steps.append(make_pipeline(ReleaseYear(), DictVectorizer(sparse=False)))
    res = make_union(*steps)
    return res

def get_model_pipe(features_pipe, scaler, estimator):
    return make_pipeline(features_pipe, scaler, estimator)

# %%
features_pipe=get_features_pipe()

# %%
model = get_model_pipe(
                        features_pipe,
                        scaler = StandardScaler(), 
                        estimator= LogisticRegression(max_iter=400
                                                     ),
                                             )
model.fit(train_docs, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('featureunion',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('pipeline-1',
#                                                  Pipeline(memory=None,
#                                                           steps=[('runtime',
#                                                                   RunTime()),
#                                                                  ('dictvectorizer',
#                                                                   DictVectorizer(dtype=<class 'numpy.float64'>,
#                                                                                  separator='=',
#                                                                                  sort=True,
#                                                                                  sparse=False))],
#                                                           verbose=False)),
#                                                 ('pipeline-2',
#                                                  Pipeline(memory=None,
#                                                           steps=[('genredummies',
#                                                                   GenreDummies()),
#                                                                  ('dictv...
#                               transformer_weights=None, verbose=False)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=400,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
test_pipe(model)
# Out:
# {'train_auc': 0.8657176119820477,
#  'test_auc': 0.9329507575055453,
#  'f1': 0.06015037593984962,
#  'precision': 0.5714285714285714,
#  'recall': 0.031746031746031744,
#  'f_05_score': 0.12987012987012986}

# %% [markdown]
# We do much worse, as expected. Despite the deceiving 93% ROC AUC in testing, our recall drops to an awful 3.1%.

# %% [markdown]
# As a final check to confirm the importance of the W2V features, let's try predicting with those two only.

# %%
def get_features_pipe():
    steps = []
    steps.append(make_pipeline(W2VFeatures(wtv, category='cast', min_cnt_movies=3)))
    steps.append(make_pipeline(W2VFeatures(wtv, category='crew', min_cnt_movies=3)))
    res = make_union(*steps)
    return res

def get_model_pipe(features_pipe, scaler, estimator):
    return make_pipeline(features_pipe, scaler, estimator)

# %%
features_pipe=get_features_pipe()

# %%
model = get_model_pipe(
                        features_pipe,
                        scaler = StandardScaler(), 
                        estimator= LogisticRegression(max_iter=400
                                                     ),
                                             )
model.fit(train_docs, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('featureunion',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('pipeline-1',
#                                                  Pipeline(memory=None,
#                                                           steps=[('w2vfeatures',
#                                                                   W2VFeatures(category='cast',
#                                                                               min_cnt_movies=3,
#                                                                               wtv=<gensim.models.word2vec.Word2Vec object at 0x0000017C881AE4C8>))],
#                                                           verbose=False)),
#                                                 ('pipeline-2',
#                                                  Pipeline(memory=None,
#                                                           steps=[('w2vfeatures',
#                                                                   W2VFeatures(category=...
#                               transformer_weights=None, verbose=False)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=400,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
test_pipe(model)
# Out:
# {'train_auc': 0.9813784366449506,
#  'test_auc': 0.9838350417369489,
#  'f1': 0.4725738396624472,
#  'precision': 0.5045045045045045,
#  'recall': 0.4444444444444444,
#  'f_05_score': 0.4912280701754385}

# %% [markdown]
# Our performance is reduced, so it seems that the Genre dummies, the Runtime and the Release Year were helping at least somewhat. But the lead stars of this predictive model are the vectors extracted from Word2Vec, as we can see we do very well using those only and nothing else.

# %%
trials = Trials()
fmin(
    objective,
    space=hyperparameter_space,
    algo=tpe.suggest,
    max_evals=2,
    trials=trials
);
# Out:
# 100%|████████████████████████████████████████████████| 2/2 [09:55<00:00, 297.66s/trial, best loss: -0.5358490566037736]

# %%
experiment_results = pd.DataFrame(trials.results)
experiment_results.sort_values(by='loss').head(8)
# Out:
#      hidden_layers     alpha  train_ROCAUC  test_ROCAUC        f1      loss  \
# 0     (50, 50, 50)  0.046599      0.996128     0.989351  0.535849 -0.535849
# 1  (100, 100, 100)  0.054225      0.996400     0.990726  0.512129 -0.512129
#
#   status
# 0     ok
# 1     ok

# %% [markdown]
# # Algorithm selection

# %% [markdown]
# Here it would make sense to try different algorithms and see how much better our predictions can get. Remember that we used a simple linear model. Even though we got very decent results, it is very likely we can do better with an ensemble model such as Gradient Boosting Classifier, or even a MLP neural network.
#
# However, I do not try those here because it takes way too much time for my computer to train any of those complex models. As said before, we still do well with our simple Logistic Regression anyway.

# %% [markdown]
# # Probability Distributions

# %% [markdown]
# To end this notebook, we'll make use of the fact that our predictive model seems to work pretty well for drawing some probability distributions regarding movies' expected IMDB votes. To do this, we treat this as several different classification problems, in which the target in each case will be numVotes<i.

# %%
y_train = train_df.numVotes
y_test = test_df.numVotes

# %% [markdown]
# We'll use the following thresholds, one for each classification model we'll make.

# %%
thresholds = [np.percentile(movies.numVotes, 10), np.percentile(movies.numVotes, 25), np.percentile(movies.numVotes, 40), \
              np.percentile(movies.numVotes, 55), np.percentile(movies.numVotes, 70), np.percentile(movies.numVotes, 80), \
             np.percentile(movies.numVotes, 85), np.percentile(movies.numVotes, 87.5), np.percentile(movies.numVotes, 90), \
              np.percentile(movies.numVotes, 91.5), np.percentile(movies.numVotes, 93), np.percentile(movies.numVotes, 95),\
              np.percentile(movies.numVotes, 96.5), np.percentile(movies.numVotes, 98),  \
              np.percentile(movies.numVotes, 99), np.percentile(movies.numVotes, 99.25)]

# %%
np.percentile(movies.numVotes, 99.5)
# Out:
# 224301.94500000062

# %%
np.percentile(movies.numVotes, 99.9)
# Out:
# 584125.500000004

# %%
def get_bools(y):
    res = []
    for t in thresholds:
        res.append(y >= t)
    return res

ys_train = get_bools(y_train)
ys_test = get_bools(y_test)

# %%
models = [
        get_model_pipe(
        features_pipe=get_features_pipe(),
        scaler=StandardScaler(),
        estimator=LogisticRegression(max_iter=400)   
    )
    for _ in range(len(thresholds))
]

# %%
for i, m in enumerate(models):
    m.fit(train_docs, ys_train[i])

# %%
def get_movie_image(id):
    response = requests.get(f'https://www.imdb.com/title/{id}/')
    soup = BeautifulSoup(response.content)
    candidates = soup.find('img',)
    return candidates.attrs['src'] if candidates else 'https://i2.wp.com/www.fryskekrite.nl/wordpress/wp-content/uploads/2017/03/No-image-available.jpg'

def render_movie(id):
    picture = get_movie_image(id)
    return f"""
    <div style="width: 80%; text-align: center">
        <a href="https://www.imdb.com/title/{id}" target="_blank">
            <img style="width: 150px; display: block; margin-left: auto; margin-right: auto;" src="{picture}"/>
        </a>
    </div>
    """

# %%
from random import randint
from itertools import compress
from PIL import Image
from io import BytesIO
import seaborn as sns

def prob_dist(tconst):
    sns.set_style("white")
    filt = [x['tconst']==tconst for x in test_docs]
    movie = list(compress(test_docs, filt))[0]
    
    # We plot the movie image on the corner
    response = requests.get(get_movie_image(tconst))
    im = Image.open(BytesIO(response.content))
    im = im.resize((int(im.size[0]*0.40), int(im.size[1]*0.36)))
    height = im.size[1]
    fig, ax = plt.subplots(figsize=(13,8))
    fig.figimage(im, 48, fig.bbox.ymax-height*0.9)
    
    # The following is to make sure the prob distribution starts and ends with zero, and to remove the inconsistencies in which
    # we can end up with Prob<0 if for example Prob(votes>Xi) < Prob(votes>X(i-1).
    preds = np.asarray([m.predict_proba([movie])[0,1] for m in models])
    preds = preds[:-1] - preds[1:]
    preds = np.where(preds<0, 0, preds)
    preds = np.insert(preds, 0,0)
    thresholds_start = np.insert(thresholds,0,10)
    
    # We add more data points to the end of the plot if this is a movie with a lot of votes:
    if movie['numVotes']>np.percentile(movies.numVotes,99):
        y_train_extra = (train_df.numVotes>np.percentile(movies.numVotes,99.5)).values
        y_train_extra2 = (train_df.numVotes>np.percentile(movies.numVotes,99.9)).values
        extra_model = get_model_pipe(
                                        features_pipe=get_features_pipe(),
                                        scaler=StandardScaler(),
                                        estimator=LogisticRegression(max_iter=400)   
                                    )
        extra_model.fit(train_docs, y_train_extra)
        preds = np.insert(preds, len(preds), extra_model.predict_proba([movie])[:,1])
        extra_model.fit(train_docs, y_train_extra2)
        preds = np.insert(preds, len(preds), extra_model.predict_proba([movie])[:,1])
        preds = np.insert(preds, len(preds),0)
        thresholds_start = np.insert(thresholds_start,len(thresholds_start),np.percentile(movies.numVotes,99.5))
        thresholds_start = np.insert(thresholds_start,len(thresholds_start),np.percentile(movies.numVotes,99.9))
        thresholds_start = np.insert(thresholds_start,len(thresholds_start),1500000)
    
    mids = [(x1 + x2) / 2 for x1, x2 in zip(thresholds_start[:-1], thresholds_start[1:])]
    
    ax = sns.lineplot(mids, preds, label='predicted distribution', marker="o")
    plt.plot([movie['numVotes'],movie['numVotes']], [0, preds.max()], color='seagreen', linewidth=1.5, label='true numVotes')
    ax.grid(color='black', linestyle='-', linewidth=0.1)
    plt.xscale("log")
    plt.yticks(np.arange(0,0.75,0.05))
    plt.legend(loc='best', fontsize=13)
    plt.xlabel('Log(numVotes)', fontsize=14, fontfamily='serif')
    plt.ylabel('Probabilty', fontsize=14, fontfamily='serif')
    plt.suptitle('{originalTitle} \n'.format(**movie), fontsize=24, fontfamily='serif')
    plt.title(' \n \n \n ({startYear:.00f}, {genres})\n'.format(**movie), fontsize=16, fontfamily='serif')

# %%
prob_dist('tt7131622')

# %%
prob_dist('tt1677720')

# %%
test_df[test_df.numVotes>300000]
# Out:
#            tconst titleType                               primaryTitle  \
# 66018   tt0451279     movie                               Wonder Woman
# 74067   tt0974015     movie                             Justice League
# 79425   tt1211837     movie                             Doctor Strange
# 80767   tt1270797     movie                                      Venom
# 82954   tt1355644     movie                                 Passengers
# 83499   tt1386697     movie                              Suicide Squad
# 83695   tt1396484     movie                                         It
# 84375   tt1431045     movie                                   Deadpool
# 85269   tt1477834     movie                                    Aquaman
# 89616   tt1677720     movie                           Ready Player One
# 90672   tt1727824     movie                          Bohemian Rhapsody
# 92708   tt1825683     movie                              Black Panther
# 93380   tt1856101     movie                          Blade Runner 2049
# 97537   tt2119532     movie                              Hacksaw Ridge
# 99637   tt2250912     movie                     Spider-Man: Homecoming
# 101867  tt2380307     movie                                       Coco
# 103612  tt2527336     movie    Star Wars: Episode VIII - The Last Jedi
# 103714  tt2543164     movie                                    Arrival
# 106612  tt2948356     movie                                   Zootopia
# 106867  tt2975590     movie         Batman v Superman: Dawn of Justice
# 108572  tt3183660     movie    Fantastic Beasts and Where to Find Them
# 109654  tt3315342     movie                                      Logan
# 110171  tt3385516     movie                          X-Men: Apocalypse
# 111061  tt3498820     movie                 Captain America: Civil War
# 111096  tt3501632     movie                             Thor: Ragnarok
# 113084  tt3748528     movie               Rogue One: A Star Wars Story
# 113332  tt3783958     movie                                 La La Land
# 114086  tt3890160     movie                                Baby Driver
# 114146  tt3896198     movie             Guardians of the Galaxy Vol. 2
# 115812  tt4154664     movie                             Captain Marvel
# 115815  tt4154756     movie                     Avengers: Infinity War
# 115816  tt4154796     movie                          Avengers: Endgame
# 117435  tt4425200     movie                       John Wick: Chapter 2
# 120628  tt4972582     movie                                      Split
# 120825  tt5013056     movie                                    Dunkirk
# 120887  tt5027774     movie  Three Billboards Outside Ebbing, Missouri
# 121038  tt5052448     movie                                    Get Out
# 123358  tt5463162     movie                                 Deadpool 2
# 123994  tt5580390     movie                         The Shape of Water
# 129448  tt6644200     movie                              A Quiet Place
# 131759  tt7286456     movie                                      Joker
#
#                                     originalTitle  isAdult  startYear endYear  \
# 66018                                Wonder Woman        0     2017.0      \N
# 74067                              Justice League        0     2017.0      \N
# 79425                              Doctor Strange        0     2016.0      \N
# 80767                                       Venom        0     2018.0      \N
# 82954                                  Passengers        0     2016.0      \N
# 83499                               Suicide Squad        0     2016.0      \N
# 83695                                          It        0     2017.0      \N
# 84375                                    Deadpool        0     2016.0      \N
# 85269                                     Aquaman        0     2018.0      \N
# 89616                            Ready Player One        0     2018.0      \N
# 90672                           Bohemian Rhapsody        0     2018.0      \N
# 92708                               Black Panther        0     2018.0      \N
# 93380                           Blade Runner 2049        0     2017.0      \N
# 97537                               Hacksaw Ridge        0     2016.0      \N
# 99637                      Spider-Man: Homecoming        0     2017.0      \N
# 101867                                       Coco        0     2017.0      \N
# 103612    Star Wars: Episode VIII - The Last Jedi        0     2017.0      \N
# 103714                                    Arrival        0     2016.0      \N
# 106612                                   Zootopia        0     2016.0      \N
# 106867         Batman v Superman: Dawn of Justice        0     2016.0      \N
# 108572    Fantastic Beasts and Where to Find Them        0     2016.0      \N
# 109654                                      Logan        0     2017.0      \N
# 110171                          X-Men: Apocalypse        0     2016.0      \N
# 111061                 Captain America: Civil War        0     2016.0      \N
# 111096                             Thor: Ragnarok        0     2017.0      \N
# 113084                                  Rogue One        0     2016.0      \N
# 113332                                 La La Land        0     2016.0      \N
# 114086                                Baby Driver        0     2017.0      \N
# 114146             Guardians of the Galaxy Vol. 2        0     2017.0      \N
# 115812                             Captain Marvel        0     2019.0      \N
# 115815                     Avengers: Infinity War        0     2018.0      \N
# 115816                          Avengers: Endgame        0     2019.0      \N
# 117435                       John Wick: Chapter 2        0     2017.0      \N
# 120628                                      Split        0     2016.0      \N
# 120825                                    Dunkirk        0     2017.0      \N
# 120887  Three Billboards Outside Ebbing, Missouri        0     2017.0      \N
# 121038                                    Get Out        0     2017.0      \N
# 123358                                 Deadpool 2        0     2018.0      \N
# 123994                         The Shape of Water        0     2017.0      \N
# 129448                              A Quiet Place        0     2018.0      \N
# 131759                                      Joker        0     2019.0      \N
#
#         runtimeMinutes                          genres  averageRating  \
# 66018            141.0    [Action, Adventure, Fantasy]            7.4
# 74067            120.0    [Action, Adventure, Fantasy]            6.4
# 79425            115.0    [Action, Adventure, Fantasy]            7.5
# 80767            112.0      [Action, Sci-Fi, Thriller]            6.7
# 82954            116.0        [Drama, Romance, Sci-Fi]            7.0
# 83499            123.0    [Action, Adventure, Fantasy]            6.0
# 83695            135.0                        [Horror]            7.3
# 84375            108.0     [Action, Adventure, Comedy]            8.0
# 85269            143.0    [Action, Adventure, Fantasy]            7.0
# 89616            140.0     [Action, Adventure, Sci-Fi]            7.5
# 90672            134.0       [Biography, Drama, Music]            8.0
# 92708            134.0     [Action, Adventure, Sci-Fi]            7.3
# 93380            164.0        [Action, Drama, Mystery]            8.0
# 97537            139.0     [Biography, Drama, History]            8.1
# 99637            133.0     [Action, Adventure, Sci-Fi]            7.4
# 101867           105.0  [Adventure, Animation, Family]            8.4
# 103612           152.0    [Action, Adventure, Fantasy]            7.1
# 103714           116.0        [Drama, Mystery, Sci-Fi]            7.9
# 106612           108.0  [Adventure, Animation, Comedy]            8.0
# 106867           151.0     [Action, Adventure, Sci-Fi]            6.5
# 108572           132.0    [Adventure, Family, Fantasy]            7.3
# 109654           137.0         [Action, Drama, Sci-Fi]            8.1
# 110171           144.0     [Action, Adventure, Sci-Fi]            6.9
# 111061           147.0     [Action, Adventure, Sci-Fi]            7.8
# 111096           130.0     [Action, Adventure, Comedy]            7.9
# 113084           133.0     [Action, Adventure, Sci-Fi]            7.8
# 113332           128.0          [Comedy, Drama, Music]            8.0
# 114086           113.0          [Action, Crime, Drama]            7.6
# 114146           136.0     [Action, Adventure, Comedy]            7.6
# 115812           123.0     [Action, Adventure, Sci-Fi]            6.9
# 115815           149.0     [Action, Adventure, Sci-Fi]            8.5
# 115816           181.0      [Action, Adventure, Drama]            8.5
# 117435           122.0       [Action, Crime, Thriller]            7.5
# 120628           117.0              [Horror, Thriller]            7.3
# 120825           106.0        [Action, Drama, History]            7.9
# 120887           115.0          [Comedy, Crime, Drama]            8.2
# 121038           104.0     [Horror, Mystery, Thriller]            7.7
# 123358           119.0     [Action, Adventure, Comedy]            7.7
# 123994           123.0     [Adventure, Drama, Fantasy]            7.3
# 129448            90.0         [Drama, Horror, Sci-Fi]            7.5
# 131759           122.0        [Crime, Drama, Thriller]            8.8
#
#         numVotes                                          cast  \
# 66018   507364.0  [nm2933757, nm1517976, nm0000705, nm0205063]
# 74067   345977.0  [nm0000255, nm2933757, nm0597388, nm3009232]
# 79425   541717.0  [nm1212722, nm0252230, nm1046097, nm0938950]
# 80767   312671.0  [nm0362766, nm0931329, nm1981893, nm2020278]
# 82954   320859.0  [nm2225369, nm0695435, nm0790688, nm0000401]
# 83499   554234.0  [nm0000226, nm0001467, nm3053338, nm0205626]
# 83695   408581.0  [nm0803889, nm5897057, nm6016511, nm6096118]
# 84375   846098.0  [nm0005351, nm1072555, nm2554352, nm4534098]
# 85269   311721.0  [nm0597388, nm1720028, nm0000353, nm0933940]
# 89616   320329.0  [nm4446467, nm4972453, nm0578853, nm2913119]
# 90672   392899.0  [nm1785339, nm2377903, nm3152605, nm5228887]
# 92708   551558.0  [nm1569276, nm0430107, nm2143282, nm1775091]
# 93380   400213.0  [nm0000148, nm0331516, nm1869101, nm1176985]
# 97537   384206.0  [nm1940449, nm0941777, nm3478396, nm1954240]
# 99637   460700.0  [nm4043618, nm0000474, nm0000375, nm0000673]
# 101867  305977.0  [nm5645519, nm0305558, nm0000973, nm0005513]
# 103612  483192.0  [nm5397459, nm3915784, nm0000434, nm0000402]
# 103714  536871.0  [nm0010736, nm0719637, nm0001845, nm0836121]
# 106612  396271.0  [nm0329481, nm0000867, nm0252961, nm2809577]
# 106867  590219.0  [nm0000255, nm0147147, nm0010736, nm0251986]
# 108572  377864.0  [nm1519666, nm2239702, nm0837223, nm0283945]
# 109654  586353.0  [nm0413168, nm0001772, nm6748436, nm2933542]
# 110171  369092.0  [nm0564215, nm1055413, nm2225369, nm0396558]
# 111061  609169.0  [nm0262635, nm0000375, nm0424060, nm1659221]
# 111096  518858.0  [nm1165110, nm1089991, nm0000949, nm0749263]
# 113084  494685.0  [nm0428065, nm0526019, nm0876138, nm0947447]
# 113332  453881.0  [nm0331516, nm1297015, nm1679669, nm0799777]
# 114086  387152.0  [nm5052065, nm1256532, nm0358316, nm2555462]
# 114146  511223.0  [nm0695435, nm0757855, nm1176985, nm0004874]
# 115812  373762.0  [nm0488953, nm0000168, nm0578853, nm0000179]
# 115815  725626.0  [nm0000375, nm1165110, nm0749263, nm0262635]
# 115816  603975.0  [nm0000375, nm0262635, nm0749263, nm1165110]
# 117435  321140.0  [nm0000206, nm1249052, nm0574534, nm3199307]
# 120628  380859.0  [nm0564215, nm5896355, nm4726634, nm4088627]
# 120825  487715.0  [nm7887725, nm4422686, nm0753314, nm0362766]
# 120887  368070.0  [nm0000531, nm0000437, nm0005377, nm2655177]
# 121038  429397.0  [nm2257207, nm4129745, nm0925966, nm0001416]
# 123358  424785.0  [nm0005351, nm0000982, nm1072555, nm5421877]
# 123994  327018.0  [nm1020089, nm0818055, nm0788335, nm0427964]
# 129448  333264.0  [nm1289434, nm1024677, nm8075925, nm7415871]
# 131759  472462.0  [nm0001618, nm0000134, nm5939164, nm0175814]
#
#                                                      crew  Classic
# 66018   [nm4243936, nm0420941, nm0374302, nm0811583, n...        1
# 74067   [nm1189346, nm0811583, nm0796950, nm0795975, n...        1
# 79425   [nm0270559, nm0220600, nm3123612, nm1803036, n...        1
# 80767   [nm2163440, nm0281508, nm0684374, nm0003298, n...        1
# 82954   [nm0605775, nm0878763, nm3123612, nm1336500, n...        1
# 83499   [nm1664042, nm0043742, nm1694619, nm0746273, n...        1
# 83695   [nm0334381, nm0615592, nm1286060, nm1560977, n...        1
# 84375   [nm0432725, nm1783265, nm1014201, nm1116660, n...        1
# 85269   [nm0918816, nm1490123, nm0424901, nm3263825, n...        1
# 89616   [nm1069736, nm0000229, nm0672015, nm2094392, n...        1
# 90672   [nm0653211, nm0001741, nm0565026, nm0604948, n...        1
# 92708   [nm3234869, nm3363032, nm1963288, nm0498278, n...        1
# 93380   [nm0467255, nm0898288, nm0266684, nm0338169, n...        1
# 97537   [nm0202704, nm0000154, nm0770938, nm0460795, n...        1
# 99637   [nm1273099, nm1218281, nm0326246, nm0197855, n...        1
# 101867  [nm0315974, nm0881279, nm2937122, nm0441735, n...        1
# 103612  [nm0006911, nm0426059, nm0000184, nm0074851, n...        1
# 103714  [nm0511482, nm0898288, nm2104063, nm5384213, n...        1
# 106612  [nm1601882, nm0397174, nm0601781, nm1158544, n...        1
# 106867  [nm0796950, nm0811583, nm0006516, nm0333060, n...        1
# 108572  [nm0006133, nm0946734, nm0746830, nm0382268, n...        1
# 109654  [nm0918083, nm0003506, nm0291082, nm0338169, n...        1
# 110171  [nm0498278, nm0001741, nm1334526, nm1002424, n...        1
# 111061  [nm0456158, nm0751577, nm0751648, nm1321655, n...        1
# 111096  [nm1293367, nm0169806, nm3069408, nm1219736, n...        1
# 113084  [nm0000184, nm2284484, nm0919363, nm0006904, n...        1
# 113332  [nm3225654, nm3227090, nm1757754, nm1344784, n...        1
# 114086  [nm0691084, nm0942367, nm0079677, nm0271479, n...        1
# 114146  [nm4160687, nm0348181, nm3966115, nm5037683, n...        1
# 115812  [nm0270559, nm1349818, nm0281396, nm4039044, n...        1
# 115815  [nm0456158, nm0751577, nm0751648, nm1321655, n...        1
# 115816  [nm0456158, nm0751577, nm0751648, nm1321655, n...        1
# 117435  [nm1177490, nm0821432, nm4401003, nm0412588, n...        1
# 120628  [nm3002063, nm0796117, nm0081514, nm0089658, n...        1
# 120825  [nm0189769, nm0634240, nm0858799, nm0001877, n...        1
# 120887  [nm0339856, nm1732981, nm0110357, nm0194446, n...        1
# 121038  [nm0002947, nm1443502, nm0089658, nm1197257, n...        1
# 123358  [nm1334526, nm0500610, nm1014201, nm1116660, n...        1
# 123994  [nm0938485, nm0868219, nm0961827, nm0197703, n...        1
# 129448  [nm0001937, nm1456816, nm1399714, nm0000881, n...        1
# 131759  [nm0177896, nm0680846, nm0798788, nm0004170, n...        1

# %%
prob_dist('tt4481514')

# %%
prob_dist('tt7923374')

# %% [markdown]
# And here I found a couple in which the model fails, just to show that even though we created a model that is very good at identifying top 1% movies, we do not always make good predictions when we go to mid or low ranges of votes.

# %%
prob_dist('tt8201852')

# %%
prob_dist('tt1727824')

# %%
prob_dist('tt12747588')
